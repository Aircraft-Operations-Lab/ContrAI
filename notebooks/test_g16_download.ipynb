# %%
from contrai.data.goes16 import generate_ash_rgb_for_datetime

png_path, rgb, dt = generate_ash_rgb_for_datetime(
    2023, 1, 30, "1600",
)

print("Ash RGB saved to:", png_path)
print("Using scan time:", dt)
# Out:
# [GOES16] Starting Ash RGB generation for 2023-01-30 1600 UTC
# [GOES16] Resolving and downloading Ash-RGB bands for 2023-01-30 1600 UTC
# [GOES16] Target datetime: 2023-01-30T16:00:00Z
# [GOES16] Day-of-year for 2023-01-30: 030
# [GOES16] Day-of-year for 2023-01-30: 030
# [GOES16] Searching for Ash-RGB channels near 2023-01-30T16:00:00Z within ±0:30:00, across 2 hour-prefixes
# [GOES16] Discovered 96 candidate files across requested prefixes.
# [GOES16] Band 11: selected OR_ABI-L1b-RadF-M6C11_G16_s20230301600209_e20230301609517_c20230301609563.nc (scan start 2023-01-30T16:00:20Z, Δt=0:00:20)
# [GOES16] Band 13: selected OR_ABI-L1b-RadF-M6C13_G16_s20230301600209_e20230301609531_c20230301609589.nc (scan start 2023-01-30T16:00:20Z, Δt=0:00:20)
# [GOES16] Band 14: selected OR_ABI-L1b-RadF-M6C14_G16_s20230301600209_e20230301609517_c20230301609584.nc (scan start 2023-01-30T16:00:20Z, Δt=0:00:20)
# [GOES16] Band 15: selected OR_ABI-L1b-RadF-M6C15_G16_s20230301600209_e20230301609524_c20230301609581.nc (scan start 2023-01-30T16:00:20Z, Δt=0:00:20)
# [GOES16] L1b output directory: images/goes16_l1b/2023/01/30/1600
# [GOES16] Downloading band 11 from s3://noaa-goes16/ABI-L1b-RadF/2023/030/16/OR_ABI-L1b-RadF-M6C11_G16_s20230301600209_e20230301609517_c20230301609563.nc
# [GOES16] Downloading band 13 from s3://noaa-goes16/ABI-L1b-RadF/2023/030/16/OR_ABI-L1b-RadF-M6C13_G16_s20230301600209_e20230301609531_c20230301609589.nc
# [GOES16] Downloading band 14 from s3://noaa-goes16/ABI-L1b-RadF/2023/030/16/OR_ABI-L1b-RadF-M6C14_G16_s20230301600209_e20230301609517_c20230301609584.nc
# [GOES16] Downloading band 15 from s3://noaa-goes16/ABI-L1b-RadF/2023/030/16/OR_ABI-L1b-RadF-M6C15_G16_s20230301600209_e20230301609524_c20230301609581.nc
# [GOES16] All requested bands downloaded successfully
# [GOES16] Building Ash RGB from local L1b files
# [GOES16] Loading brightness temperature from images/goes16_l1b/2023/01/30/1600/OR_ABI-L1b-RadF-M6C11_G16_s20230301600209_e20230301609517_c20230301609563.nc
# [GOES16] Loading brightness temperature from images/goes16_l1b/2023/01/30/1600/OR_ABI-L1b-RadF-M6C13_G16_s20230301600209_e20230301609531_c20230301609589.nc
# [GOES16] Loading brightness temperature from images/goes16_l1b/2023/01/30/1600/OR_ABI-L1b-RadF-M6C14_G16_s20230301600209_e20230301609517_c20230301609584.nc
# [GOES16] Loading brightness temperature from images/goes16_l1b/2023/01/30/1600/OR_ABI-L1b-RadF-M6C15_G16_s20230301600209_e20230301609524_c20230301609581.nc
# [GOES16] Converting GOES fixed grid coordinates to lat/lon
# [GOES16] Applying Ash RGB spectral differences and scaling
# [GOES16] Creating target grid: lat [15.0, 40.0], lon [-90.0, -30.0], res 0.02 deg
# [GOES16] Resampling channel to target grid
# [GOES16] Resampling channel to target grid
# [GOES16] Resampling channel to target grid
# [GOES16] Ash RGB array constructed successfully
# [GOES16] Saving Ash RGB PNG to images/goes16_ash_rgb/2023/01/30/1600/ash_rgb_0p02deg.png
# [GOES16] Ash RGB generation complete (scan time 2023-01-30T16:00:00Z)
# Ash RGB saved to: images/goes16_ash_rgb/2023/01/30/1600/ash_rgb_0p02deg.png
# Using scan time: 2023-01-30 16:00:00
